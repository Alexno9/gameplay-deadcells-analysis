# %% [markdown]
# Montando o ambiente (Streamlit + NgRok)

# %%
# Instalando a biblioteca no sistema
# Rodas duas vezes para funcionar
# !pip install -q streamlit
# Out:
#      |████████████████████████████████| 7.1MB 2.7MB/s
#      |████████████████████████████████| 4.4MB 48.5MB/s
#      |████████████████████████████████| 102kB 10.7MB/s
#      |████████████████████████████████| 112kB 48.8MB/s
#      |████████████████████████████████| 122kB 50.0MB/s
# ...
# ERROR: google-colab 1.0.0 has requirement ipykernel~=4.10, but you'll have ipykernel 5.3.4 which is incompatible.

# %%
# Download do cliente ngrok, dado pelo próprio site
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Out:
# --2020-08-02 16:32:02--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 34.194.108.77, 54.80.22.251, 34.206.168.28, ...
# Connecting to bin.equinox.io (bin.equinox.io)|34.194.108.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  6.52MB/s    in 2.0s
#
# 2020-08-02 16:32:05 (6.52 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]

# %%
# Extrair pacote zipado
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %% [markdown]
# Execução das portas

# %%
get_ipython().system_raw('./ngrok http 8501 &')

# !curl -s http://localhost:4040/api/tunnels | python3 -c \
         "import sys, json; print('Execute the next cell and the go to the following URL: ' + json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# Execute the next cell and the go to the following URL: https://039b2754d9ee.ngrok.io

# %% [markdown]
# Chamar abaixo o código em python que contenha streamlit

# %%
# !streamlit run /content/explorandodeadcells.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://34.80.16.41:8501
